# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Dell/Eda/cleaned_Hyderabad_real_estate.csv")

# %%
df['Price_per_sqft'] = df['Price (in lakhs)'] * 100000 / df['Size (in sqft)']
sns.histplot(x=df['Price_per_sqft'])
# Out:
# <Axes: xlabel='Price_per_sqft', ylabel='Count'>

# %%
df=df[df['Price_per_sqft']<50000]
df
# Out:
#                                   Name    Location  BHK   Type  \
# 0               Fortune Butterfly City     Kadthal    3   Flat
# 1                The Cascades Neopolis     Kokapet    5   Flat
# 2                    Sreenidhi Neocity  Sadasivpet    3   Flat
# 3    Sri Tirumala Millennium Phase III    Mallapur    3   Flat
# 4      Sri Jagathswapna Spanesta Villa    Bacharam    5  Villa
# ..                                 ...         ...  ...    ...
# 527                   Primark Eco Nest    Kompally    3   Flat
# 528                    Poulomi Palazzo     Kokapet    4   Flat
# 529                    Sage By Raghava      Kollur    4  Villa
# 530                        Sew Estella    Kondapur    4   Flat
# 531                 Vardhan Green Oaks  Sainikpuri    3   Flat
#
#      Price (in lakhs)  Size (in sqft)              Status Delivery Date  \
# 0               23.99          2093.0  Under Construction     May, 2015
# 1               32.03          4825.0  Under Construction     Mar, 2030
# 2               35.99          2093.0  Under Construction     Jun, 2026
# 3               41.99          1521.0  Under Construction     Oct, 2027
# 4               47.99          5500.0  Under Construction     Apr, 2026
# ..                ...             ...                 ...           ...
# 527             34.10          2165.0  Under Construction     Oct, 2027
# 528             36.11         10160.0  Under Construction     Mar, 2028
# 529             36.40          6370.0  Under Construction     Aug, 2029
# 530             36.42          3160.0       Ready to Move     Jul, 2015
# 531             41.83          2114.0       Ready to Move     Aug, 2024
#
#                                      Listed By Delivery_Month  Delivery_Year  \
# 0                       FORTUNE BUTTERFLY CITY            May           2015
# 1                                       Seller            Mar           2030
# 2    GHR Lakshmi Infra and Urban Blocks Realty            Jun           2026
# 3                                    Developer            Oct           2027
# 4                              Ananthaa Spaces            Apr           2026
# ..                                         ...            ...            ...
# 527                                     Seller            Oct           2027
# 528                         Lakshinfraprojects            Mar           2028
# 529                                     Seller            Aug           2029
# 530                            MAGNA SOLITAIRE            Jul           2015
# 531                                     Seller            Aug           2024
#
#      Price_per_sqft
# 0       1146.201624
# 1        663.834197
# 2       1719.541328
# 3       2760.683761
# 4        872.545455
# ..              ...
# 527     1575.057737
# 528      355.413386
# 529      571.428571
# 530     1152.531646
# 531     1978.713340
#
# [526 rows x 12 columns]

# %%
sns.histplot(x=df['Price_per_sqft'],kde=True)
# Out:
# <Axes: xlabel='Price_per_sqft', ylabel='Count'>

# %%
sns.histplot(x=df["BHK"],hue=df["Type"])
# Out:
# <Axes: xlabel='BHK', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.countplot(x=df['Delivery_Year'])
plt.xticks(rotation=45) 
plt.show()

# %%
sns.barplot(x="BHK",y="Size (in sqft)",data=df,hue="Type")
# Out:
# <Axes: xlabel='BHK', ylabel='Size (in sqft)'>

# %%
sns.scatterplot(x=df["Size (in sqft)"],y=df['Price (in lakhs)'])
# Out:
# <Axes: xlabel='Size (in sqft)', ylabel='Price (in lakhs)'>

# %%
df['Listed By'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
sns.kdeplot(x='Price (in lakhs)',data=df)
# Out:
# <Axes: xlabel='Price (in lakhs)', ylabel='Density'>

# %%
sns.barplot(x=df["Type"],y=df["Price (in lakhs)"])
# Out:
# <Axes: xlabel='Type', ylabel='Price (in lakhs)'>
